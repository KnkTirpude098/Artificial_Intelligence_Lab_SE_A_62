# %% [markdown]
# <a href="https://colab.research.google.com/github/KnkTirpude098/Artificial_Intelligence_Lab_SE_A_62/blob/master/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Factorial Calculator
#
# This program calculates the factorial of a non-negative integer entered by the user. It handles basic input validation.

# %%
def calculate_factorial(n):
    """
    Calculates the factorial of a non-negative integer.
    """
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        factorial = 1
        for i in range(1, n + 1):
            factorial *= i
        return factorial

# Prompt the user for input
while True:
    try:
        num_str = input("Enter a non-negative integer to compute its factorial: ")
        num = int(num_str)
        if num >= 0:
            break
        else:
            print("Please enter a non-negative integer.")
    except ValueError:
        print("Invalid input. Please enter an integer.")

# Calculate the factorial
result = calculate_factorial(num)

# Display the result
print(f"The factorial of {num} is: {result}")
# Out:
# Enter a non-negative integer to compute its factorial: 4
# The factorial of 4 is: 24
